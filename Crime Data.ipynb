# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
crime_df = pd.read_csv("MD_Crime_Data.csv")
crime_df
# Out:
#           JURISDICTION  YEAR  POPULATION  MURDER  RAPE  ROBBERY  AGG. ASSAULT  \
# 0      Allegany County  1975       79655       3     5       20           114
# 1      Allegany County  1976       83923       2     2       24            59
# 2      Allegany County  1977       82102       3     7       32            85
# 3      Allegany County  1978       79966       1     2       18            81
# 4      Allegany County  1979       79721       1     7       18            84
# ...                ...   ...         ...     ...   ...      ...           ...
# 1099  Worcester County  2016       51255       3    17       39            93
# 1100  Worcester County  2017       51408       2    26       43           106
# 1101  Worcester County  2018       51304       0    12       24            88
# 1102  Worcester County  2019       51606       0    12       24            94
# 1103  Worcester County  2020       52191       1    31       39           163
#
# ...

# %%
crime_df['JURISDICTION'].unique()
# Out:
# array(['Allegany County', 'Anne Arundel County', 'Baltimore City',
#        'Baltimore County', 'Calvert County', 'Caroline County',
#        'Carroll County', 'Cecil County', 'Charles County',
#        'Dorchester County', 'Frederick County', 'Garrett County',
#        'Harford County', 'Howard County', 'Kent County',
#        'Montgomery County', "Prince George's County",
#        "Queen Anne's County", 'Somerset County', "St. Mary's County",
#        'Talbot County', 'Washington County', 'Wicomico County',
#        'Worcester County'], dtype=object)

# %%
crime = crime_df.dropna()
crime
# Out:
#           JURISDICTION  YEAR  POPULATION  MURDER  RAPE  ROBBERY  AGG. ASSAULT  \
# 1      Allegany County  1976       83923       2     2       24            59
# 2      Allegany County  1977       82102       3     7       32            85
# 3      Allegany County  1978       79966       1     2       18            81
# 4      Allegany County  1979       79721       1     7       18            84
# 5      Allegany County  1980       80461       2    12       26            79
# ...                ...   ...         ...     ...   ...      ...           ...
# 1099  Worcester County  2016       51255       3    17       39            93
# 1100  Worcester County  2017       51408       2    26       43           106
# 1101  Worcester County  2018       51304       0    12       24            88
# 1102  Worcester County  2019       51606       0    12       24            94
# 1103  Worcester County  2020       52191       1    31       39           163
#
# ...

# %%
crime.dtypes
# Out:
# JURISDICTION                                              object
# YEAR                                                       int64
# POPULATION                                                 int64
# MURDER                                                     int64
# RAPE                                                       int64
# ROBBERY                                                    int64
# AGG. ASSAULT                                               int64
# B & E                                                      int64
# LARCENY THEFT                                              int64
# M/V THEFT                                                  int64
# GRAND TOTAL                                                int64
# PERCENT CHANGE                                           float64
# VIOLENT CRIME TOTAL                                        int64
# VIOLENT CRIME PERCENT                                    float64
# ...

# %%
overall_rates = crime[['YEAR', 'JURISDICTION','OVERALL CRIME RATE PER 100,000 PEOPLE']]
overall_rates
# Out:
#       YEAR      JURISDICTION  OVERALL CRIME RATE PER 100,000 PEOPLE
# 1     1976   Allegany County                                 2532.1
# 2     1977   Allegany County                                 2693.0
# 3     1978   Allegany County                                 2664.9
# 4     1979   Allegany County                                 2912.7
# 5     1980   Allegany County                                 3074.8
# ...    ...               ...                                    ...
# 1099  2016  Worcester County                                 3876.7
# 1100  2017  Worcester County                                 3793.2
# 1101  2018  Worcester County                                 3023.2
# 1102  2019  Worcester County                                 2774.9
# 1103  2020  Worcester County                                 2943.0
#
# [1080 rows x 3 columns]

# %%
overall_rates.groupby('JURISDICTION').size()
# Out:
# JURISDICTION
# Allegany County           45
# Anne Arundel County       45
# Baltimore City            45
# Baltimore County          45
# Calvert County            45
# Caroline County           45
# Carroll County            45
# Cecil County              45
# Charles County            45
# Dorchester County         45
# Frederick County          45
# Garrett County            45
# Harford County            45
# Howard County             45
# Kent County               45
# Montgomery County         45
# Prince George's County    45
# Queen Anne's County       45
# Somerset County           45
# St. Mary's County         45
# Talbot County             45
# Washington County         45
# Wicomico County           45
# Worcester County          45
# dtype: int64

# %%
alleg = overall_rates[(overall_rates['JURISDICTION']== 'Allegany County')]
aa_County = overall_rates[(overall_rates['JURISDICTION']== 'Anne Arundel County')]
balt_City = overall_rates[(overall_rates['JURISDICTION']== 'Baltimore City')]
balt_Count = overall_rates[(overall_rates['JURISDICTION']== 'Baltimore County')]
Calvert_County = overall_rates[(overall_rates['JURISDICTION']== 'Calvert County')]
Caroline_County = overall_rates[(overall_rates['JURISDICTION']== 'Caroline County')]
Carroll_County  = overall_rates[(overall_rates['JURISDICTION']== 'Carroll County')]
Cecil_County = overall_rates[(overall_rates['JURISDICTION']== 'Cecil County')]
Charles_County = overall_rates[(overall_rates['JURISDICTION']== 'Charles County')]
Dorchester_County = overall_rates[(overall_rates['JURISDICTION']== 'Dorchester County')]
Frederick_County = overall_rates[(overall_rates['JURISDICTION']== 'Frederick County')]
Garrett_County  = overall_rates[(overall_rates['JURISDICTION']== 'Garrett County ')]
Harford_County = overall_rates[(overall_rates['JURISDICTION']== 'Harford County')]
Howard_County = overall_rates[(overall_rates['JURISDICTION']== 'Howard County')]
Kent_County  = overall_rates[(overall_rates['JURISDICTION']== 'Kent County ')]
Montgomery_County = overall_rates[(overall_rates['JURISDICTION']== 'Montgomery County')]
Prince_Georges_County  = overall_rates[(overall_rates['JURISDICTION']== 'Prince Georges County')]
Queen_Annes_County = overall_rates[(overall_rates['JURISDICTION']== 'Queen Annes County')]
Somerset_County  = overall_rates[(overall_rates['JURISDICTION']== 'Somerset County')]
Talbot_County   = overall_rates[(overall_rates['JURISDICTION']== 'Talbot County')]
Washington_County  = overall_rates[(overall_rates['JURISDICTION']== 'Washington County')]
Wicomico_County  = overall_rates[(overall_rates['JURISDICTION']== 'Wicomico County')]
Worcester_County  = overall_rates[(overall_rates['JURISDICTION']== 'Worcester County')]

# %%
#plot each county?
alleg.plot(x='YEAR', y= 'OVERALL CRIME RATE PER 100,000 PEOPLE')
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
aa_County.plot(x='YEAR', y= 'OVERALL CRIME RATE PER 100,000 PEOPLE')
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
balt_City.plot(x='YEAR', y= 'OVERALL CRIME RATE PER 100,000 PEOPLE')
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
balt_Count.plot(x='YEAR', y= 'OVERALL CRIME RATE PER 100,000 PEOPLE')
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
Calvert_County.plot(x='YEAR', y= 'OVERALL CRIME RATE PER 100,000 PEOPLE')
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
Caroline_County.plot(x='YEAR', y= 'OVERALL CRIME RATE PER 100,000 PEOPLE')
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
Worcester_County.plot(x='YEAR', y= 'OVERALL CRIME RATE PER 100,000 PEOPLE')
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
y= overall_rates.groupby('YEAR').sum()
y
# Out:
#       OVERALL CRIME RATE PER 100,000 PEOPLE
# YEAR
# 1976                               101929.7
# 1977                                98815.0
# 1978                                99620.2
# 1979                               112201.8
# 1980                               115658.1
# 1981                               114877.9
# 1982                               105219.8
# 1983                                93308.5
# 1984                                91558.5
# 1985                                95397.2
# 1986                               101723.0
# 1987                                99434.4
# 1988                               100136.0
# 1989                                99549.5
# 1990                               102041.0
# 1991                               107720.2
# 1992                               106896.0
# 1993                               104107.2
# 1994                               103227.8
# 1995                               104796.9
# ...

# %%
y.plot(y='OVERALL CRIME RATE PER 100,000 PEOPLE')
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
crime.sum()
# Out:
# JURISDICTION                                             Allegany CountyAllegany CountyAllegany CountyA...
# YEAR                                                                                               2157840
# POPULATION                                                                                       231684527
# MURDER                                                                                               21418
# RAPE                                                                                                 72974
# ROBBERY                                                                                             631072
# AGG. ASSAULT                                                                                        910250
# B & E                                                                                              2002629
# LARCENY THEFT                                                                                      6003578
# ...

# %%
crime.groupby('YEAR').sum()
# Out:
#       POPULATION  MURDER  RAPE  ROBBERY  AGG. ASSAULT  B & E  LARCENY THEFT  \
# YEAR
# 1976     4144000     352  1323    12234         12247  56311         133912
# 1977     4139000     333  1432    12083         14791  57904         131043
# 1978     4143000     337  1470    12821         15635  58875         133371
# 1979     4149000     406  1616    13738         17283  62605         144634
# 1980     4192211     399  1678    16455         17115  71094         151338
# 1981     4261000     421  1654    18085         17619  70722         151796
# 1982     4265000     429  1592    15366         18787  60498         142079
# 1983     4304000     367  1407    14939         17957  52662         126862
# 1984     4349000     354  1639    13097         19344  51475         123051
# 1985     4392000     350  1711    13275         21411  53155         125646
# 1986     4463000     397  1947    13570         21192  55578         132278
# ...

# %%
dist_by_type = crime[['YEAR', 'VIOLENT CRIME TOTAL', 'VIOLENT CRIME PERCENT', 
       'VIOLENT CRIME PERCENT CHANGE', 'PROPERTY CRIME TOTALS',
       'PROPERTY CRIME PERCENT', 'PROPERTY CRIME PERCENT CHANGE']]
dist_by_type
# Out:
#       YEAR  VIOLENT CRIME TOTAL  VIOLENT CRIME PERCENT  \
# 1     1976                   87                    4.1
# 2     1977                  127                    5.7
# 3     1978                  102                    4.8
# 4     1979                  110                    4.7
# 5     1980                  119                    4.8
# ...    ...                  ...                    ...
# 1099  2016                  152                    7.6
# 1100  2017                  177                    9.1
# 1101  2018                  124                    8.0
# 1102  2019                  130                    9.1
# 1103  2020                  234                   15.2
#
#       VIOLENT CRIME PERCENT CHANGE  PROPERTY CRIME TOTALS  \
# 1                            -38.7                   2038
# 2                             46.0                   2084
# 3                            -19.7                   2029
# 4                              7.8                   2212
# ...

# %%
dist_by_type.groupby('YEAR').sum()
# Out:
#       VIOLENT CRIME TOTAL  VIOLENT CRIME PERCENT  \
# YEAR
# 1976                26156                  219.2
# 1977                28639                  219.5
# 1978                30263                  229.0
# 1979                33043                  238.9
# 1980                35647                  232.3
# 1981                37779                  224.4
# 1982                36174                  239.3
# 1983                34670                  264.8
# 1984                34434                  275.9
# 1985                36747                  310.3
# 1986                37106                  313.4
# 1987                35272                  307.6
# 1988                37413                  300.7
# 1989                40082                  329.4
# 1990                43835                  321.3
# 1991                46266                  301.7
# 1992                48930                  313.1
# 1993                49294                  312.4
# ...
